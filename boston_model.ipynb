# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\CONCORDIA SEM 1\AI\Boston.csv")

# %%
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
df.shape
# Out:
# (506, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
df.describe().T
# Out:
#             count        mean         std        min         25%        50%  \
# Unnamed: 0  506.0  253.500000  146.213884    1.00000  127.250000  253.50000
# crim        506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# zn          506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# indus       506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# chas        506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# nox         506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# rm          506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# age         506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# dis         506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# rad         506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# tax         506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'crim'}>, <Axes: title={'center': 'zn'}>,
#         <Axes: title={'center': 'indus'}>],
#        [<Axes: title={'center': 'chas'}>,
#         <Axes: title={'center': 'nox'}>, <Axes: title={'center': 'rm'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'dis'}>, <Axes: title={'center': 'rad'}>,
#         <Axes: title={'center': 'tax'}>,
#         <Axes: title={'center': 'ptratio'}>],
#        [<Axes: title={'center': 'black'}>,
#         <Axes: title={'center': 'lstat'}>,
#         <Axes: title={'center': 'medv'}>, <Axes: >]], dtype=object)

# %%
for i in df.columns:
    sns.kdeplot(data=df,x=i)
    plt.show()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
for i in df.columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
for i in ['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','black','lstat']:
    sns.scatterplot(data=df,x=i,y='medv')
    plt.show()

# %%
#outlier treatment only done for non targer and independent variable

def wisker(col):
    q1,q3=np.percentile(col,[25,75])
    iqr=q3-q1
    lw=q1-1.5*iqr
    uw=q1+1.5*iqr
    return lw,uw

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
for i in ['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','black','lstat']:
     lw,uw=wisker(df[i])
     df[i]=np.where(df[i]<lw,lw,df[i])
     df[i]=np.where(df[i]>uw,uw,df[i])

# %%
for i in df.columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
 df.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
sns.kdeplot(x=np.log(df['medv']))
# Out:
# <Axes: xlabel='medv', ylabel='Density'>

# %%
from scipy.stats import boxcox
df['medv'],lmd=boxcox(df['medv'])

# %%
df['medv']
# Out:
# 0      4.572936
# 1      4.365582
# 2      5.336943
# 3      5.254955
# 4      5.428607
#          ...
# 501    4.436621
# 502    4.273824
# 503    4.564629
# 504    4.401354
# 505    3.277431
# Name: medv, Length: 506, dtype: float64

# %%
#Start bulding model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
#create x,y

x=df.drop('medv',axis=1)
y=df['medv']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
#split data into train and test

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
#fit the model

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#predict y
y_predict=model.predict(x_test)
y_predict
# Out:
# array([5.00272138, 5.42795083, 3.49754371, 4.88502465, 3.63476727,
#        4.49081287, 3.64562403, 3.42622755, 4.28796501, 4.03694279,
#        4.13628478, 3.91065405, 2.96660447, 4.338732  , 4.11588777,
#        4.39488125, 4.09770627, 3.03397613, 5.57672205, 3.5337669 ,
#        4.8883819 , 5.03373613, 3.05274074, 4.38894136, 3.70495488,
#        3.47693951, 4.62730668, 3.47948511, 3.92134106, 3.95663459,
#        4.33974947, 4.69235694, 4.31423408, 4.29593822, 3.3774723 ,
#        4.05195665, 5.26855008, 4.22340191, 4.1024078 , 4.70758665,
#        3.25698901, 5.20130205, 5.6728771 , 3.98238484, 4.84092826,
#        3.61357416, 3.42624481, 4.83462171, 3.87755871, 5.25485666,
#        4.31843635, 5.46549941, 3.49955805, 4.82906753, 5.76311612,
#        4.32639203, 3.71240017, 5.25520758, 4.62077899, 3.49498794,
#        4.58717039, 5.16383834, 5.3717612 , 3.96775788, 4.65043288,
#        3.36685721, 3.78714739, 4.85979134, 5.161571  , 3.3719126 ,
# ...

# %%
#get r2
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2_score(y_test,y_predict)
# Out:
# 0.7398254309009962

# %%
#get coifficient
coef=model.coef_
for i,j in zip(x_train.columns,coef):
    print(f"{i}={j}")
# Out:
# Unnamed: 0=-0.0004099685589691482
# crim=-0.09537038057412943
# zn=0.0037273697869139033
# indus=0.009294686562000946
# chas=2.914335439641036e-15
# nox=-1.4201743306346262
# rm=0.18993826103192318
# age=0.0005211419553920967
# dis=-0.12436846819943649
# rad=0.03573727816920833
# tax=-0.0007942147458503412
# ptratio=-0.0741713812619122
# black=0.0013476499170144386
# lstat=-0.09008500305225457

# %%
#calculate RMSE
np.sqrt(mean_squared_error(y_test,y_predict))
# Out:
# np.float64(0.3811897744036818)
